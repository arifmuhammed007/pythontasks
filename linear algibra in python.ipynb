# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Question 1: Data Scaling and Centering (Scalars, Vectors, and Matrices)
# You have a dataset representing customer ages: [25, 30, 35, 40, 45].
# a. Represent this data as a NumPy vector. b. Calculate the mean and standard deviation of this vector. c. Normalize (standardize) this vector by subtracting the mean and dividing by the standard deviation. Explain why data normalization is important in data analysis.

# %%
age = np.array([25,30,35,40,45])
age_mean = age.mean()
age_std = age.std()
normal_std = (age - age_mean)/age_std
print(age_mean)
print(age_std)
print(normal_std)
"""🧠 Key Benefits of Normalization:

Improves model accuracy and performance

Avoids dominance of large-scale features

Helps convergence in gradient descent

Essential for distance-based algorithms (e.g., KNN, SVM)
"""
# Out:
# 35.0
# 7.0710678118654755
# [-1.41421356 -0.70710678  0.          0.70710678  1.41421356]
# '🧠 Key Benefits of Normalization:\n\nImproves model accuracy and performance\n\nAvoids dominance of large-scale features\n\nHelps convergence in gradient descent\n\nEssential for distance-based algorithms (e.g., KNN, SVM)\n'

# %% [markdown]
# Question 2: Feature Engineering - Combining Metrics (Vector Operations)
# A marketing campaign tracked two metrics for five different ads:
# clicks = np.array([100, 150, 120, 180, 90])
# conversions = np.array([5, 8, 6, 10, 4])
# Assume each conversion is worth 10 units of "value" and each click is worth 0.1 units of "value".
# a. Create a vector representing the total value generated by clicks for each ad. b. Create a vector representing the total value generated by conversions for each ad. c. Calculate the total combined value for each ad. d. Visualize the clicks, conversions, and total_value vectors using separate bar plots or a combined line plot, clearly labeling each.

# %%
clicks = np.array([100, 150, 120, 180, 90])
conversions = np.array([5, 8, 6, 10, 4])
clicks_value = 0.1
coversion_value = 10

#a)a. Create a vector representing the total value generated by clicks for each ad.
click_values = clicks*clicks_value
print(value_generated_by_clicks)
# Out:
# [10. 15. 12. 18.  9.]

# %%
#b) b. Create a vector representing the total value generated by conversions for each ad
value_generated_by_conversion = conversions*coversion_value
print(value_generated_by_conversion)
# Out:
# [ 50  80  60 100  40]

# %%
#c. Calculate the total combined value for each ad
total_combined_value = click_values + value_generated_by_conversion
print(total_combined_value)
# Out:
# [ 60.  95.  72. 118.  49.]

# %%
#d. Visualize the clicks, conversions, and total_value vectors using separate bar plots or a combined line plot, clearly labeling each.
import matplotlib.pyplot as plt

ads = np.arange(1, 6)

plt.figure(figsize=(12, 6))

# Bar plot for clicks and conversions value
plt.subplot(1, 2, 1)
bar_width = 0.35
plt.bar(ads - bar_width/2, click_values, width=bar_width, label='Click Value', color='skyblue')
plt.bar(ads + bar_width/2, value_generated_by_conversion, width=bar_width, label='Conversion Value', color='lightgreen')
plt.xlabel('Ad Number')
plt.ylabel('Value')
plt.title('Click & Conversion Value per Ad')
plt.xticks(ads)
plt.legend()

# Line plot for total values
plt.subplot(1, 2, 2)
plt.plot(ads, total_combined_value , marker='o', linestyle='-', color='orange', label='Total Value')
plt.xlabel('Ad Number')
plt.ylabel('Total Value')
plt.title('Total Value per Ad')
plt.xticks(ads)
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# Question 3: Sales Performance Analysis (Matrix Operations)
# You have monthly sales data for three different products over two quarters:
# Python
# sales_q1 = np.array([[100, 120, 90],  # Product A, B, C for Jan, Feb, Mar
#                      [110, 130, 95],
#                      [105, 125, 88]])
#
# sales_q2 = np.array([[130, 140, 100],  # Product A, B, C for Apr, May, Jun
#                      [125, 135, 98],
#                      [135, 145, 105]])
#
# a. Calculate the total sales for each product across both quarters. b. If the unit profit for Product A is $5, Product B is $7, and Product C is $4, represent these profits as a vector. c. Calculate the total profit for each month in Q1 using matrix multiplication. Explain what the resulting matrix/vector represents.

# %%
sales_q1 = np.array([[100, 120, 90],  # Product A, B, C for Jan, Feb, Mar
                     [110, 130, 95],
                     [105, 125, 88]])

sales_q2 = np.array([[130, 140, 100],  # Product A, B, C for Apr, May, Jun
                     [125, 135, 98],
                     [135, 145, 105]])

# %%
#a. Calculate the total sales for each product across both quarters
total_sales = sales_q1 + sales_q2
print(total_sales)
print("\n")
total_sales_each_product = np.sum(total_sales,axis = 0)
print(total_sales_each_product)
# Out:
# [[230 260 190]
#  [235 265 193]
#  [240 270 193]]
#
#
# [705 795 576]

# %%
#b. If the unit profit for Product A is $5, Product B is $7, and Product C is $4, represent these profits as a vector
profit_vector = np.array([5,7,4])

# %%
#c. Calculate the total profit for each month in Q1 using matrix multiplication. Explain what the resulting matrix/vector represents.
monthly = sales_q1@profit_vector
print(monthly)
# Out:
# [1700 1840 1752]

# %% [markdown]
# Question 4: Anomaly Detection - Outlier Scores (Vector Operations - Dot Product)
# You have customer spending habits, represented by two features: average_transaction_value and number_of_transactions. customer_data = np.array([[50, 10], [60, 12], [200, 5], [55, 11], [45, 9]]) You want to assign an "anomaly score" to each customer. A simple way is to take the dot product with a "weight vector" that emphasizes unusual behavior. Let weights = np.array([0.2, -0.8]) (where a positive weight for average_transaction_value and negative for number_of_transactions might indicate high-value, low-frequency buyers as potentially anomalous).
# a. Calculate the anomaly score for each customer using the dot product. b. Identify the customer with the highest anomaly score. What might this score suggest about this customer's behavior?

# %%
customer_data = np.array([[50, 10], [60, 12], [200, 5], [55, 11], [45, 9]])
weights = np.array([0.2, -0.8])

# %%
#)a. Calculate the anomaly score for each customer using the dot product
anomaly_score = customer_data @ weights
print(anomaly_score)
# Out:
# [ 2.   2.4 36.   2.2  1.8]

# %%
#b. Identify the customer with the highest anomaly score. What might this score suggest about this customer's behavior?
most_anomalous_index = np.argmax(anomaly_score)
print(most_anomalous_index)
# Out:
# 2

# %% [markdown]
# Question 5: Feature Combination Visualization (Vector Operations - Cross Product)
# Imagine you have two features, x and y, representing attributes of a data point, and you want to understand how they "interact" to form a third derived feature z. While not a direct application of cross-product in data features, visualize how two 3D vectors combine using the cross-product to conceptually represent orthogonal relationships.
# Consider two feature vectors in a 3D space: feature1 = np.array([1, 0, 0]) and feature2 = np.array([0, 1, 0]).

# %%
feature1 = np.array([1, 0, 0])
feature2 = np.array([0, 1, 0])
z = np.cross(feature1,feature2)

from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.quiver(0, 0, 0, feature1[0], feature1[1], feature1[2], color='r', label='Feature 1')
ax.quiver(0, 0, 0, feature2[0], feature2[1], feature2[2], color='g', label='Feature 2')
ax.quiver(0, 0, 0, z[0], z[1], z[2], color='b', label='Cross Product')

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.legend()

plt.show()

# %% [markdown]
# Question 6: Data Consistency Check (Determinants and Inverse)
# You are given a system of linear equations representing relationships between different advertising channels' effectiveness. Channel 1 (x), Channel 2 (y), Channel 3 (z) 2x + y - z = 8 x - 3y + 2z = -1 3x + 2y - z = 12
# Represent this system in the form Ax = b.
# a. Calculate the determinant of matrix A. b. What does the value of the determinant tell you about the existence and uniqueness of the solution to this system? If the determinant is non-zero, compute the inverse of A.

# %%
A = np.array([[2,1,-1],
              [1,-3,2],
              [3,2,-1]])
B = np.array([8,-1,12])

# %%
#a. Calculate the determinant of matrix A
det_A = np.linalg.det(A)
print(det_A)
# Out:
# -6.0

# %%
#b. What does the value of the determinant tell you about the existence and uniqueness of the solution to this system? If the determinant is non-zero, compute the inverse of A.

A_inv = np.linalg.inv(A)
print(A_inv)
# Out:
# [[ 0.16666667  0.16666667  0.16666667]
#  [-1.16666667 -0.16666667  0.83333333]
#  [-1.83333333  0.16666667  1.16666667]]

# %% [markdown]
# Question 7: Understanding Data Transformation (Eigenvalues and Eigenvectors)
# You have a 2x2 covariance matrix of two features: covariance_matrix = np.array([[4, 1], [1, 3]])
# a. Compute the eigenvalues and eigenvectors of this covariance matrix. b. Interpret the significance of the eigenvectors. How do they relate to the principal components of the data? What do the corresponding eigenvalues tell you about the variance along these directions?

# %%
covariance_matrix = np.array([[4, 1], [1, 3]])

# %%
#a. Compute the eigenvalues and eigenvectors of this covariance matrix
eigenvalue,eigenvectors = np.linalg.eig(covariance_matrix)
print("eigenvalue:",eigenvalue)
print("eigenvectors\n:",eigenvectors)
# Out:
# eigenvalue: [4.61803399 2.38196601]
# eigenvectors
# : [[ 0.85065081 -0.52573111]
#  [ 0.52573111  0.85065081]]

# %% [markdown]
# Question 8: Resource Allocation Optimization (Solving Linear Systems)
# A manufacturing company produces three types of products (P1, P2, P3). Each product requires different amounts of raw materials (M1, M2, M3).
# P1: 2 units of M1, 1 unit of M2, 1 unit of M3
# P2: 1 unit of M1, 3 units of M2, 2 units of M3
# P3: 1 unit of M1, 2 units of M2, 1 unit of M3
# You have a total of 100 units of M1, 150 units of M2, and 80 units of M3 available.
# a. Set up a system of linear equations to determine how many units of each product (P1, P2, P3) can be produced using all available raw materials. Represent this as Ax = b. b. Solve this system using numpy.linalg.solve(). c. Interpret the solution. What does it tell the company about its production capacity given the raw material constraints? Consider what might happen if the system were singular or inconsistent

# %%
#a. Set up a system of linear equations to determine how many units of each product (P1, P2, P3) can be produced using all available raw materials. 
A = np.array([[2, 1, 1],
              [1, 3, 2],
              [1, 2, 1]])

B = np.array([100, 150, 80])

# %%
# b. Solve this system using numpy.linalg.solve().
x = np.linalg.solve(A,B)
print(x)
# Out:
# [15. -5. 75.]

# %% [markdown]
# #c. Interpret the solution. What does it tell the company about its production capacity given the raw material constraints? Consider what might happen if the system were singular or inconsistent
#
# All 100 units of M1, 150 units of M2, and 80 units of M3 will be fully used.
#
# This is an optimal allocation — every resource is efficiently distributed across the product lines.
